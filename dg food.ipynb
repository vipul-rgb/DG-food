# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
dt = pd.read_csv("G:DataScience project practice//industrial project Datasciencce//Project_Data_2.csv" , index_col = 0)
dt
# Out:
#                        1990 1991 1992 1993 1994 1995  1996  1997  1998  1999  \
# Sales of Wheat in tons
# Afghanistan             436  429  422  415  407  397   397   387   374   373
# Albania                  42   40   41   42   42   43    42    44    43    42
# Algeria                  45   44   44   43   43   42    43    44    45    46
# American Samoa           42   14    4   18   17   22     0    25    12     8
# Andorra                  39   37   35   33   32   30    28    23    24    22
# ...                     ...  ...  ...  ...  ...  ...   ...   ...   ...   ...
# Wallis et Futuna        126  352   64  174  172   93   123   213   107   105
# West Bank and Gaza       55   54   54   52   52   50    49    46    44    42
# Yemen                   265  261  263  253  250  244   233   207   194   175
# Zambia                  436  456  494  526  556  585   602   626   634   657
# Zimbabwe                409  417  415  419  426  439   453   481   392   430
#
# ...

# %%
dt.index.names = ['Country']
dt.columns.names = ['years']
dt.head()
# Out:
# years          1990 1991 1992 1993 1994 1995  1996  1997  1998  1999  2000  \
# Country
# Afghanistan     436  429  422  415  407  397   397   387   374   373   346
# Albania          42   40   41   42   42   43    42    44    43    42    40
# Algeria          45   44   44   43   43   42    43    44    45    46    48
# American Samoa   42   14    4   18   17   22     0    25    12     8     8
# Andorra          39   37   35   33   32   30    28    23    24    22    20
#
# years           2001  2002  2003 2004 2005 2006 2007
# Country
# Afghanistan      326   304   308  283  267  251  238
# Albania           34    32    32   29   29   26   22
# Algeria           49    50    51   52   53   55   56
# American Samoa     6     5     6    9   11    9    5
# Andorra           20    21    18   19   18   17   19

# %% [markdown]
# # Basic Analysis

# %%
# So there is some commas in the position 54 , first we have to solve that problem first by replacing 

dt = dt.replace(',','', regex= True)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 207 entries, Afghanistan to Zimbabwe
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1990    207 non-null    object
#  1   1991    207 non-null    object
#  2   1992    207 non-null    object
#  3   1993    207 non-null    object
#  4   1994    207 non-null    object
#  5   1995    207 non-null    object
#  6   1996    207 non-null    int64
#  7   1997    207 non-null    int64
#  8   1998    207 non-null    int64
#  9   1999    207 non-null    int64
#  10  2000    207 non-null    int64
#  11  2001    207 non-null    int64
#  12  2002    207 non-null    int64
#  13  2003    207 non-null    int64
#  14  2004    207 non-null    object
#  15  2005    207 non-null    object
#  16  2006    207 non-null    object
#  17  2007    207 non-null    object
# dtypes: int64(8), object(10)
# memory usage: 30.7+ KB

# %%
#As the data of sum columns are in object we have to convert the data type 
dt['1990']= pd.to_numeric(dt["1990"])
dt['1991']= pd.to_numeric(dt["1991"])
dt['1992']= pd.to_numeric(dt["1992"])
dt['1993']= pd.to_numeric(dt["1993"])
dt['1994']= pd.to_numeric(dt["1994"])
dt['1995']= pd.to_numeric(dt["1995"])
dt['2004']= pd.to_numeric(dt["2004"])
dt['2005']= pd.to_numeric(dt["2005"])
dt['2006']= pd.to_numeric(dt["2006"])
dt['2007']= pd.to_numeric(dt["2007"])

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 207 entries, Afghanistan to Zimbabwe
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1990    207 non-null    int64
#  1   1991    207 non-null    int64
#  2   1992    207 non-null    int64
#  3   1993    207 non-null    int64
#  4   1994    207 non-null    int64
#  5   1995    207 non-null    int64
#  6   1996    207 non-null    int64
#  7   1997    207 non-null    int64
#  8   1998    207 non-null    int64
#  9   1999    207 non-null    int64
#  10  2000    207 non-null    int64
#  11  2001    207 non-null    int64
#  12  2002    207 non-null    int64
#  13  2003    207 non-null    int64
#  14  2004    207 non-null    int64
#  15  2005    207 non-null    int64
#  16  2006    207 non-null    int64
#  17  2007    207 non-null    int64
# dtypes: int64(18)
# memory usage: 30.7+ KB

# %%
dt.isnull().sum()  # this used to check if there is any missing value
# Out:
# years
# 1990    0
# 1991    0
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# dtype: int64

# %%
dt.isna().sum()
# Out:
# years
# 1990    0
# 1991    0
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# dtype: int64

# %%
dt.describe()
# Out:
# years         1990         1991         1992         1993         1994  \
# count   207.000000   207.000000   207.000000   207.000000   207.000000
# mean    196.966184   196.468599   192.811594   191.173913   188.724638
# std     232.385067   229.329664   224.805522   220.093799   216.750218
# min       0.000000     3.000000     3.000000     3.000000     0.000000
# 25%      42.000000    40.000000    37.500000    37.000000    34.000000
# 50%      96.000000    93.000000    91.000000    88.000000    89.000000
# 75%     290.000000   315.500000   320.000000   316.500000   314.000000
# max    1485.000000  1477.000000  1463.000000  1442.000000  1414.000000
#
# years         1995        1996        1997        1998        1999  \
# count   207.000000  207.000000  207.000000  207.000000  207.000000
# mean    187.942029  178.898551  180.975845  178.120773  180.473430
# std     212.477587  193.786752  192.272421  188.843079  195.062942
# ...

# %%
dt.duplicated()
# Out:
# Country
# Afghanistan           False
# Albania               False
# Algeria               False
# American Samoa        False
# Andorra               False
#                       ...
# Wallis et Futuna      False
# West Bank and Gaza    False
# Yemen                 False
# Zambia                False
# Zimbabwe              False
# Length: 207, dtype: bool

# %%
dt.duplicated().sum()
# Out:
# 1

# %%
dt=dt.drop_duplicates()

# %%
dt.duplicated().sum()
# Out:
# 0

# %%
dt.corr()
# Out:
# years      1990      1991      1992      1993      1994      1995      1996  \
# years
# 1990   1.000000  0.995229  0.993114  0.988326  0.978302  0.974892  0.939410
# 1991   0.995229  1.000000  0.994496  0.992820  0.981779  0.980976  0.946518
# 1992   0.993114  0.994496  1.000000  0.995464  0.985372  0.988806  0.953242
# 1993   0.988326  0.992820  0.995464  1.000000  0.995461  0.993652  0.956928
# 1994   0.978302  0.981779  0.985372  0.995461  1.000000  0.989341  0.955631
# 1995   0.974892  0.980976  0.988806  0.993652  0.989341  1.000000  0.962024
# 1996   0.939410  0.946518  0.953242  0.956928  0.955631  0.962024  1.000000
# 1997   0.922688  0.933170  0.939231  0.943718  0.943034  0.953220  0.988442
# 1998   0.910121  0.919637  0.929787  0.932758  0.932555  0.946155  0.977147
# 1999   0.876697  0.883457  0.892664  0.906827  0.920231  0.919509  0.954562
# 2000   0.875809  0.884110  0.892973  0.901854  0.910689  0.918329  0.948024
# ...

# %% [markdown]
# # graphs

# %%
sns.displot(dt['1990'])
plt.show()

# %%
sns.displot(dt['1990']),
sns.displot(dt['1995']),
sns.displot(dt['2000']),
sns.displot(dt['2005'])
plt.show()

# %%
sns.distplot(dt['1990']),
plt.show()

# %%
sns.distplot(dt['1990']),
sns.distplot(dt['1991']),
sns.distplot(dt['2007']),
plt.show()

# %%
sns.boxplot(dt['1990'])
plt.show()
dt['1990'].min()
dt['1990'].max()
# Out:
# 1485

# %%
sns.boxplot(dt['1990']),
sns.boxplot(dt['1991']),
sns.boxplot(dt['2007'])
plt.show()

# %%
sns.lineplot(dt["2007"])  # here we see that avg order quantatiy is about 600 - 700 tons
plt.show()

# %%
sns.lineplot(dt) # here we see that the avg order size from countries is about 600 - 900 throught all years
plt.show()

# %%
scatter_plot = dt1.plot(kind ='scatter', x ='Pc2',y='Pc1' , figsize=(16,8))

# %%
scatter_plot = dt1.plot(kind ='scatter', x ='Pc2',y='Pc1' , figsize=(15,7))
for i , Country in enumerate(dt.index):
    scatter_plot.annotate(Country ,(dt1.iloc[i].Pc2 ,dt1.iloc[i].Pc1 ))

# %% [markdown]
# # applying dimensionality reduction with pca

# %%
from sklearn.decomposition import PCA

PCA = PCA(n_components=2)
PCA.fit(dt)
# Out:
# PCA(n_components=2)

# %%
Tf = PCA.transform(dt)

# %%
dt1 = pd.DataFrame(Tf)
dt1.index = dt.index 
dt1.columns = ['Pc1','Pc2']
dt1.head(10)
# Out:
#                             Pc1         Pc2
# Country
# Afghanistan          728.615747  203.369628
# Albania             -616.874916    4.639332
# Algeria             -572.877637  -36.910935
# American Samoa      -720.658287    5.383528
# Andorra             -665.378159   10.959309
# Angola               986.938230  294.246220
# Anguilla            -622.466806  -14.579436
# Antigua and Barbuda -727.232021   -5.452822
# Argentina           -511.823805   60.968687
# Armenia             -458.128382  -79.055554

# %%
PCA.explained_variance_ratio_
# Out:
# array([0.91781709, 0.06075895])

# %%
# %matplotlib inline
scatter_plot = dt1.plot(kind ='scatter', x ='Pc2',y='Pc1' , figsize=(16,8))

# %%
scatter_plot = dt1.plot(kind ='scatter', x ='Pc2',y='Pc1' , figsize=(15,7))
for i , Country in enumerate(dt.index):
    scatter_plot.annotate(Country ,(dt1.iloc[i].Pc2 ,dt1.iloc[i].Pc1 ))

# %% [markdown]
# # Data Normalization

# %%
from sklearn.preprocessing import normalize 

dt1['country_mean'] = pd.Series(dt.mean(axis = 1), index = dt1.index)
country_mean_max = dt1['country_mean'].max()
country_mean_min = dt1['country_mean'].min()

country_mean_scaling = (dt1.country_mean-country_mean_min) / country_mean_max
dt1['country_mean_scaling'] = pd.Series(country_mean_scaling, index = dt1.index)
dt1.head()
# Out:
#                        Pc1         Pc2  country_mean  country_mean_scaling
# Country
# Afghanistan     728.615747  203.369628    353.333333              0.329731
# Albania        -616.874916    4.639332     36.944444              0.032420
# Algeria        -572.877637  -36.910935     47.388889              0.042234
# American Samoa -720.658287    5.383528     12.277778              0.009240
# Andorra        -665.378159   10.959309     25.277778              0.021457

# %% [raw]
#  # Max data

# %%
dt1['country_sum'] = pd.Series(dt.sum(axis=1), index=dt1.index)
country_sum_max = dt1['country_sum'].max()
country_sum_min = dt1['country_sum'].min()
country_sum_scaled = (dt1.country_sum-country_sum_min) / country_sum_max
dt1['country_sum_scaled'] = pd.Series(country_sum_scaled, index=dt1.index)
dt1.head()
# Out:
#                        Pc1         Pc2  country_mean  country_mean_scaling  \
# Country
# Afghanistan     728.615747  203.369628    353.333333              0.329731
# Albania        -616.874916    4.639332     36.944444              0.032420
# Algeria        -572.877637  -36.910935     47.388889              0.042234
# American Samoa -720.658287    5.383528     12.277778              0.009240
# Andorra        -665.378159   10.959309     25.277778              0.021457
#
#                 country_sum  country_sum_scaled
# Country
# Afghanistan            6360            0.329731
# Albania                 665            0.032420
# Algeria                 853            0.042234
# American Samoa          221            0.009240
# Andorra                 455            0.021457

# %%
dt1.plot(kind='scatter', x='Pc2', y='Pc1', s=dt1['country_sum_scaled']*100, figsize=(16,8))
plt.show()

# %% [raw]
# # difference from data throught out years

# %%
dt1['country_change'] = pd.Series(dt['2007']-dt['1990'], index=dt1.index)
country_change_max = dt1['country_change'].max()
country_change_min = dt1['country_change'].min()
country_change_scaled = (dt1.country_change - country_change_min) / country_change_max
dt1['country_change_scaled'] = pd.Series(country_change_scaled, index=dt1.index)
dt1[['country_change','country_change_scaled']].head()
# Out:
#                 country_change  country_change_scaled
# Country
# Afghanistan               -198               0.850840
# Albania                    -20               1.224790
# Algeria                     11               1.289916
# American Samoa             -37               1.189076
# Andorra                    -20               1.224790

# %%
dt1.plot(kind='scatter', x='Pc2', y='Pc1', s=dt1['country_change_scaled']*100, figsize=(16,8))
# Out:
# <Axes: xlabel='Pc2', ylabel='Pc1'>

# %% [markdown]
# # Algorithms

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)
clusters = kmeans.fit(dt)

# %% [raw]
# # adding cluster columns to data frame

# %%
dt1['cluster'] = pd.Series(clusters.labels_, index=dt1.index)
dt1.head()
# Out:
#                        Pc1         Pc2  country_mean  country_mean_scaling  \
# Country
# Afghanistan     728.615747  203.369628    353.333333              0.329731
# Albania        -616.874916    4.639332     36.944444              0.032420
# Algeria        -572.877637  -36.910935     47.388889              0.042234
# American Samoa -720.658287    5.383528     12.277778              0.009240
# Andorra        -665.378159   10.959309     25.277778              0.021457
#
#                 country_sum  country_sum_scaled  country_change  \
# Country
# Afghanistan            6360            0.329731            -198
# Albania                 665            0.032420             -20
# Algeria                 853            0.042234              11
# American Samoa          221            0.009240             -37
# Andorra                 455            0.021457             -20
#
#                 country_change_scaled  cluster
# Country
# Afghanistan                  0.850840        1
# ...

# %%
# plot the data 
#sns.set_style('whitegrid')
sns.lmplot(data=dt1, x="Pc2", y="Pc1" , hue = 'cluster')
plt.show()

# %%
scatter_plot = dt1.plot(kind ='scatter', x ='Pc2',y='Pc1' , figsize=(15,7))
for i , Country in enumerate(dt.index):
    scatter_plot.annotate(Country ,(dt1.iloc[i].Pc2 ,dt1.iloc[i].Pc1 ))

# %%
sns.countplot(dt1, x="cluster")
plt.show()

# %%
sse = []
k_rng = range(1,10)

for k in k_rng:
    kmeans = KMeans(n_clusters = k)
    kmeans.fit(dt1[['Pc2','Pc1']])
    sse.append(kmeans.inertia_)

# %%
plt.xlabel('k')
plt.ylabel('sum of squared error')
plt.plot(k_rng,sse)
plt.show()

# %%
dt1[(dt1['cluster']==1) & (dt1.index)]
# Out:
#                                   Pc1         Pc2  country_mean  \
# Country
# Afghanistan                728.615747  203.369628    353.333333
# Angola                     986.938230  294.246220    413.444444
# Bolivia                    366.154649  192.473469    267.000000
# Botswana                  1121.084178 -503.626941    448.166667
# Burkina Faso               532.815045 -408.938741    310.166667
# Burundi                   1122.277018 -655.789470    449.833333
# Cape Verde                 810.934466  136.114983    372.888889
# Central African Republic  1000.151019 -355.101301    419.833333
# Chad                       937.428068 -472.269892    406.444444
# China                      372.896274  121.330611    269.666667
# Congo, Rep.                800.100018 -453.287186    375.277778
# Cote d'Ivoire             1077.740962 -583.993961    438.888889
# Congo, Dem. Rep.          1410.392501 -716.056350    519.055556
# ...

# %%
a=dt1[(dt1['cluster']==1) & (dt1.index)]

# %%
a.value_counts().sum()
# Out:
# 50

# %%
dt1[(dt1['cluster']==2) & (dt1.index)]
# Out:
#                           Pc1         Pc2  country_mean  country_mean_scaling  \
# Country
# Bangladesh        1419.200722  242.745384    515.444444              0.482067
# Bhutan            1739.105057  569.491075    587.722222              0.549987
# Cambodia          2535.351670  223.942675    778.611111              0.729366
# Korea, Dem. Rep.  2142.989382  438.999930    686.611111              0.642913
# Djibouti          3794.943714  579.144190   1064.166667              0.997703
# Kiribati          2231.180790  864.558608    702.888889              0.658209
# Mali              1728.680424  -28.156978    589.500000              0.551658
# Mauritania        1743.070522  -51.503566    594.333333              0.556199
# Namibia           1598.169580  106.010511    555.000000              0.519238
# Philippines       1968.092481  337.270679    644.666667              0.603498
# Sierra Leone      1982.748688 -710.955513    653.111111              0.611433
# ...

# %%
b=dt1[(dt1['cluster']==2) & (dt1.index)]

# %%
b.value_counts().sum()
# Out:
# 16

# %%
dt1[(dt1['cluster']==0) & (dt1.index)]
# Out:
#                            Pc1         Pc2  country_mean  \
# Country
# Albania            -616.874916    4.639332     36.944444
# Algeria            -572.877637  -36.910935     47.388889
# American Samoa     -720.658287    5.383528     12.277778
# Andorra            -665.378159   10.959309     25.277778
# Anguilla           -622.466806  -14.579436     35.611111
# ...                        ...         ...           ...
# Vanuatu              20.685004  215.941478    186.000000
# Venezuela          -599.902397  -10.599538     40.888889
# Wallis et Futuna   -234.989629  123.017572    126.222222
# West Bank and Gaza -588.802850   14.388582     43.388889
# Yemen                55.668856  177.493964    194.333333
#
#                     country_mean_scaling  country_sum  country_sum_scaled  \
# Country
# Albania                         0.032420          665            0.032420
# Algeria                         0.042234          853            0.042234
# ...

# %%
c=dt1[(dt1['cluster']==0) & (dt1.index)]

# %%
c.value_counts().sum()
# Out:
# 140
